# %% [markdown]
# # Project 2, Investigating CSV file reading with Pandas
#
# ## Makayla Marshall 3/6/2023

# %% [markdown]
# ## Reading in the file:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datafile = "LiteracySurveyFall2022.csv"
df = pd.read_csv(datafile)

# %% [markdown]
# ## Looking at file contents:

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which course are you currently enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
df['Race/ethnicity'].value_counts()
# Out:
# White/Caucasian                                                  52
# Hispanic or Latino                                               31
# Black/African American                                           13
# Asian                                                            11
# Choose not to reply                                               5
# Hispanic or Latino;White/Caucasian                                5
# Hispanic or Latino;Black/African American                         4
# Multi-Racial                                                      3
# Asian;Black/African American;White/Caucasian;Multi-Racial         2
# Black/African American;White/Caucasian;Multi-Racial               1
# Asian;White/Caucasian                                             1
# Hispanic or Latino;White/Caucasian;Multi-Racial                   1
# American Indian/Native American/Alaska Native;White/Caucasian     1
# American Indian/Native American/Alaska Native;Asian               1
# ...

# %% [markdown]
# ## Editing columns' names:

# %%
df.rename(columns=str.lower, inplace=True) ##make the columns' names lowercase

# %% [markdown]
# ## Making a new file: (hear_events)

# %%
## make a new dataframe for just how they heard about ccm and if they did any of the events
hear_events = df[['gender', 'race/ethnicity', 'age ', 'which course are you currently enrolled in?',
       'on a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in computer science, information technology or game development?',
       'how did you hear about county college of morris? [ccm web site]',
       'how did you hear about county college of morris? [social media]',
       'how did you hear about county college of morris? [community event]',
       'how did you hear about county college of morris? [family member or friend]',
       'how did you hear about county college of morris? [current ccm student]',
       'how did you hear about county college of morris? [ccm alumni]',
       'how did you hear about county college of morris? [high school teacher]',
       'how did you hear about county college of morris? [high school counselor]',
       'how did you hear about county college of morris? [in-app advertisement]',
       'how did you hear about county college of morris? [employer]',
       'how did you hear about county college of morris? [billboard]',
       'how did you hear about county college of morris? [television]',
       'how did you hear about county college of morris? [radio]',
       'how did you hear about county college of morris? [home mailer]',
       'how did you hear about county college of morris? [other]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [open house]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [instant decision day]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [on-campus information session]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [titans tuesday (virtual) information session]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [women who dare]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [regional college fair]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [hs sharetime information session]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [challenger program]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [cybersecurity information protection program participation ]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [information session at my high school]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [campus visit with my high school]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [campus visit (individual)]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [workforce development class]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [corporate training]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [teen arts festival]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [summer camp at ccm]',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [hour of code]']]

# %% [markdown]
# ## Renaming the columns for hear_events

# %%
hear_events.rename(
    columns=({'age ':'age', 'race/ethnicity':'race', 'which course are you currently enrolled in?':'course',
       'on a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in computer science, information technology or game development?':'interest',
       'how did you hear about county college of morris? [ccm web site]':'hear_ccm_website',
       'how did you hear about county college of morris? [social media]':'hear_social_media',
       'how did you hear about county college of morris? [community event]':'hear_community_event',
       'how did you hear about county college of morris? [family member or friend]':'hear_family_friend',
       'how did you hear about county college of morris? [current ccm student]':'hear_ccm_student',
       'how did you hear about county college of morris? [ccm alumni]':'hear_ccm_alumni',
       'how did you hear about county college of morris? [high school teacher]':'hear_hs_teacher',
       'how did you hear about county college of morris? [high school counselor]':'hear_hs_counselor',
       'how did you hear about county college of morris? [in-app advertisement]':'hear_in_app_ad',
       'how did you hear about county college of morris? [employer]':'hear_employer',
       'how did you hear about county college of morris? [billboard]':'hear_billboard',
       'how did you hear about county college of morris? [television]':'hear_tv',
       'how did you hear about county college of morris? [radio]':'hear_radio',
       'how did you hear about county college of morris? [home mailer]':'hear_home_mail',
       'how did you hear about county college of morris? [other]':'hear_other',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [open house]':'event_open_house',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [instant decision day]':'event_inst_dec_day',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [on-campus information session]':'event_campus_info_sess',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [titans tuesday (virtual) information session]':'event_titans_tuesday_info_sess',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [women who dare]':'event_women_who_dare',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [regional college fair]':'event_regional_college_fair',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [hs sharetime information session]':'event_hs_sharetime_info_sess',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [challenger program]':'event_challenger_program',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [cybersecurity information protection program participation ]':'event_cybersecurity_info_protection_program',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [information session at my high school]':'event_hs_info_sess',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [campus visit with my high school]':'event_campus_visit_w_hs',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [campus visit (individual)]':'event_campus_visit',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [workforce development class]':'event_workforce_development_class',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [corporate training]':'event_corporate_training',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [teen arts festival]':'event_teen_arts_festival',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [summer camp at ccm]':'event_ccm_summer_camp',
       'prior to applying to college, did you participate in any of the following events or activities at the county college of morris and/or with the department of information technologies, if at all? [hour of code]':'event_hour_of_code'}), 
    inplace=True
)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10936\1821288006.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hear_events.rename(

# %% [markdown]
# ## hear_events

# %%
hear_events
# Out:
#     gender                                               race             age  \
# 0    Woman                                 Hispanic or Latino  18 and younger
# 1    Woman                                    White/Caucasian           21-24
# 2    Woman                                    White/Caucasian           19-20
# 3      Man                                    White/Caucasian           19-20
# 4      Man                                    White/Caucasian           19-20
# ..     ...                                                ...             ...
# 126  Woman                                       Multi-Racial           21-24
# 127  Woman  American Indian/Native American/Alaska Native;...           19-20
# 128    Man                                 Hispanic or Latino           19-20
# 129  Woman                                 Hispanic or Latino           35-64
# 130  Woman                                 Hispanic or Latino           19-20
#
# ...

# %% [markdown]
# ## hear_events value counts

# %%
hear_events.gender.value_counts()
# Out:
# Woman                77
# Man                  52
# Prefer not to say     2
# Name: gender, dtype: int64

# %%
hear_events.race.value_counts()
# Out:
# White/Caucasian                                                  52
# Hispanic or Latino                                               31
# Black/African American                                           13
# Asian                                                            11
# Choose not to reply                                               5
# Hispanic or Latino;White/Caucasian                                5
# Hispanic or Latino;Black/African American                         4
# Multi-Racial                                                      3
# Asian;Black/African American;White/Caucasian;Multi-Racial         2
# Black/African American;White/Caucasian;Multi-Racial               1
# Asian;White/Caucasian                                             1
# Hispanic or Latino;White/Caucasian;Multi-Racial                   1
# American Indian/Native American/Alaska Native;White/Caucasian     1
# American Indian/Native American/Alaska Native;Asian               1
# ...

# %%
hear_events.race = hear_events.race.str.replace('American Indian/Native American/Alaska Native;Asian', 'Multi-Racial')
hear_events.race = hear_events.race.str.replace('American Indian/Native American/Alaska Native;White/Caucasian', 'Multi-Racial')
hear_events.race = hear_events.race.str.replace('Hispanic or Latino;White/Caucasian;Multi-Racial', 'Multi-Racial')
hear_events.race = hear_events.race.str.replace('Asian;White/Caucasian', 'Multi-Racial')
hear_events.race = hear_events.race.str.replace('Black/African American;White/Caucasian;Multi-Racial', 'Multi-Racial')
hear_events.race = hear_events.race.str.replace('Asian;Black/African American;White/Caucasian;Multi-Racial', 'Multi-Racial')
hear_events.race = hear_events.race.str.replace('Asian;Multi-Racial', 'Multi-Racial')
hear_events.race = hear_events.race.str.replace('Hispanic or Latino;Black/African American', 'Multi-Racial')
hear_events.race = hear_events.race.str.replace('Hispanic or Latino;White/Caucasian', 'Multi-Racial')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10936\1271263887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hear_events.race = hear_events.race.str.replace('American Indian/Native American/Alaska Native;Asian', 'Multi-Racial')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10936\1271263887.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hear_events.race = hear_events.race.str.replace('American Indian/Native American/Alaska Native;White/Caucasian', 'Multi-Racial')
# ...

# %%
hear_events.to_csv('Hear_EventsOfLiteracySurvey.csv')

# %% [markdown]
# ## Working with hear_events as the new datafile (df2)

# %%
datafile2 = "Hear_EventsOfLiteracySurvey.csv"
df2 = pd.read_csv(datafile2)

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'gender', 'race', 'age', 'course', 'interest',
#        'hear_ccm_website', 'hear_social_media', 'hear_community_event',
#        'hear_family_friend', 'hear_ccm_student', 'hear_ccm_alumni',
#        'hear_hs_teacher', 'hear_hs_counselor', 'hear_in_app_ad',
#        'hear_employer', 'hear_billboard', 'hear_tv', 'hear_radio',
#        'hear_home_mail', 'hear_other', 'event_open_house',
#        'event_inst_dec_day', 'event_campus_info_sess',
#        'event_titans_tuesday_info_sess', 'event_women_who_dare',
#        'event_regional_college_fair', 'event_hs_sharetime_info_sess',
#        'event_challenger_program',
#        'event_cybersecurity_info_protection_program', 'event_hs_info_sess',
#        'event_campus_visit_w_hs', 'event_campus_visit',
#        'event_workforce_development_class', 'event_corporate_training',
#        'event_teen_arts_festival', 'event_ccm_summer_camp',
#        'event_hour_of_code'],
#       dtype='object')

# %%
print('df2 gender value counts:', df2.gender.value_counts(), sep='\n', end='\n\n')
print('df2 race value counts:', df2.race.value_counts(), sep='\n', end='\n\n')
print('df2 course value counts:', df2.course.value_counts(), sep='\n', end='\n\n')
print('df2 interest value counts:', df2.interest.value_counts(), sep='\n', end='\n\n')
# Out:
# df2 gender value counts:
# Woman                77
# Man                  52
# Prefer not to say     2
# Name: gender, dtype: int64
#
# df2 race value counts:
# White/Caucasian           52
# Hispanic or Latino        31
# Multi-Racial              19
# Black/African American    13
# Asian                     11
# Choose not to reply        5
# Name: race, dtype: int64
#
# df2 course value counts:
# CMP 135 Computer Concepts with Applications     81
# CMP 101 Computer Information Literacy           28
# CMP 126 Computer Technology and Applications    22
# Name: course, dtype: int64
#
# df2 interest value counts:
# 3    54
# 2    32
# 1    26
# 4    12
# 5     7
# Name: interest, dtype: int64

# %% [markdown]
# ## Looking at the courses:

# %%
df2.groupby(['gender','course']).count()
# Out:
#                                                                 Unnamed: 0  \
# gender            course
# Man               CMP 101 Computer Information Literacy                  8
#                   CMP 126 Computer Technology and Applications          12
#                   CMP 135 Computer Concepts with Applications           32
# Prefer not to say CMP 101 Computer Information Literacy                  1
#                   CMP 126 Computer Technology and Applications           1
# Woman             CMP 101 Computer Information Literacy                 19
#                   CMP 126 Computer Technology and Applications           9
#                   CMP 135 Computer Concepts with Applications           49
#
#                                                                 race  age  \
# gender            course
# Man               CMP 101 Computer Information Literacy            8    8
#                   CMP 126 Computer Technology and Applications    12   12
# ...

# %%
df2.groupby(['race','course']).count()
# Out:
#                                                                      Unnamed: 0  \
# race                   course
# Asian                  CMP 101 Computer Information Literacy                  1
#                        CMP 135 Computer Concepts with Applications           10
# Black/African American CMP 101 Computer Information Literacy                  4
#                        CMP 126 Computer Technology and Applications           4
#                        CMP 135 Computer Concepts with Applications            5
# Choose not to reply    CMP 101 Computer Information Literacy                  2
#                        CMP 126 Computer Technology and Applications           3
# Hispanic or Latino     CMP 101 Computer Information Literacy                  8
#                        CMP 126 Computer Technology and Applications           2
#                        CMP 135 Computer Concepts with Applications           21
# ...

# %%
df2.groupby(['course', 'interest']).count()
# Out:
#                                                        Unnamed: 0  gender  \
# course                                       interest
# CMP 101 Computer Information Literacy        1                  4       4
#                                              2                  5       5
#                                              3                 15      15
#                                              4                  3       3
#                                              5                  1       1
# CMP 126 Computer Technology and Applications 1                  3       3
#                                              2                 11      11
#                                              3                  6       6
#                                              4                  1       1
#                                              5                  1       1
# CMP 135 Computer Concepts with Applications  1                 19      19
# ...

# %% [markdown]
# ## Insights:
# #### The CMP 135 Computer Concepts with Applications course was most popular, among men and women, but not those preferring not to say (the smallest group). It also was most popular in most races.
# #### The students from the CMP 126 Computer Technology and Applications course had the least amount of interest in taking another course.
#
# ###

# %% [markdown]
# ## Looking at how they heard about ccm:

# %%
## How did they hear about ccm value counts:
print('df2 heard from ccm website counts:', df2.hear_ccm_website.value_counts(), sep='\n', end='\n\n')
print('df2 heard from social media counts:', df2.hear_social_media.value_counts(), sep='\n', end='\n\n')
print('df2 heard from community event counts:', df2.hear_community_event.value_counts(), sep='\n', end='\n\n')
print('df2 heard from family friend counts:', df2.hear_family_friend.value_counts(), sep='\n', end='\n\n')
print('df2 heard from current ccm student counts:', df2.hear_ccm_student.value_counts(), sep='\n', end='\n\n')
print('df2 heard from ccm alumni counts:', df2.hear_ccm_alumni.value_counts(), sep='\n', end='\n\n')
print('df2 heard from highschool teacher counts:', df2.hear_hs_teacher.value_counts(), sep='\n', end='\n\n')
print('df2 heard from highschool counselor counts:', df2.hear_hs_counselor.value_counts(), sep='\n', end='\n\n')
print('df2 heard from an ad on an app counts:', df2.hear_in_app_ad.value_counts(), sep='\n', end='\n\n')
print('df2 heard from an employer counts:', df2.hear_employer.value_counts(), sep='\n', end='\n\n')
print('df2 heard from a billboard counts:', df2.hear_billboard.value_counts(), sep='\n', end='\n\n')
print('df2 heard from tv counts:', df2.hear_tv.value_counts(), sep='\n', end='\n\n')
print('df2 heard from radio counts:', df2.hear_radio.value_counts(), sep='\n', end='\n\n')
print('df2 heard from home mail counts:', df2.hear_home_mail.value_counts(), sep='\n', end='\n\n')
print('df2 heard from other counts:', df2.hear_other.value_counts(), sep='\n', end='\n\n')
# Out:
# df2 heard from ccm website counts:
# No              77
# Yes             38
# Don't recall    16
# Name: hear_ccm_website, dtype: int64
#
# df2 heard from social media counts:
# No              91
# Yes             25
# Don't recall    15
# Name: hear_social_media, dtype: int64
#
# df2 heard from community event counts:
# No              97
# Yes             21
# Don't recall    13
# Name: hear_community_event, dtype: int64
#
# df2 heard from family friend counts:
# Yes             95
# No              29
# Don't recall     7
# Name: hear_family_friend, dtype: int64
#
# df2 heard from current ccm student counts:
# Yes             67
# No              53
# Don't recall    11
# Name: hear_ccm_student, dtype: int64
#
# df2 heard from ccm alumni counts:
# No              73
# Yes             42
# Don't recall    16
# Name: hear_ccm_alumni, dtype: int64
#
# df2 heard from highschool teacher counts:
# Yes             70
# No              50
# Don't recall    11
# ...

# %% [markdown]
# ## Insights:
# #### The most common way to hear about a CCM computing class was through a family friend, with 95 reports confirming that.
# ##### Other common ways were through a highschool teacher or counselor,  with 70 and 76 reports confirming that as well.
# #### It seems that CCM computing courses are spread most commonly through word of mouth, person-to-person.

# %% [markdown]
# ## Looking at which events they attended:

# %%
## Which event did they attend:
print('df2 attended open house counts:', df2.event_open_house.value_counts(), sep='\n', end='\n\n')
print('df2 attended instant decision day counts:', df2.event_inst_dec_day.value_counts(), sep='\n', end='\n\n')
print('df2 attended campus info session counts:', df2.event_campus_info_sess.value_counts(), sep='\n', end='\n\n')
print('df2 attended titans tuesday info session counts:', df2.event_titans_tuesday_info_sess.value_counts(), sep='\n', end='\n\n')
print('df2 attended women who dare counts:', df2.event_women_who_dare.value_counts(), sep='\n', end='\n\n')
print('df2 attended regional college fair counts:', df2.event_regional_college_fair.value_counts(), sep='\n', end='\n\n')
print('df2 attended highschool sharetime info session counts:', df2.event_hs_sharetime_info_sess.value_counts(), sep='\n', end='\n\n')
print('df2 attended challenger program counts:', df2.event_challenger_program.value_counts(), sep='\n', end='\n\n')
print('df2 attended cybersecurity info protection program counts:', df2.event_cybersecurity_info_protection_program.value_counts(), sep='\n', end='\n\n')
print('df2 attended highschool info session counts:', df2.event_hs_info_sess.value_counts(), sep='\n', end='\n\n')
print('df2 attended campus visit with highschool counts:', df2.event_campus_visit_w_hs.value_counts(), sep='\n', end='\n\n')
print('df2 attended individual campus visit counts:', df2.event_campus_visit.value_counts(), sep='\n', end='\n\n')
print('df2 attended workforce development class counts:', df2.event_workforce_development_class.value_counts(), sep='\n', end='\n\n')
print('df2 attended corporate training counts:', df2.event_corporate_training.value_counts(), sep='\n', end='\n\n')
print('df2 attended teen arts festival counts:', df2.event_teen_arts_festival.value_counts(), sep='\n', end='\n\n')
print('df2 attended ccm summer camp counts:', df2.event_ccm_summer_camp.value_counts(), sep='\n', end='\n\n')
print('df2 attended hour of code counts:', df2.event_hour_of_code.value_counts(), sep='\n', end='\n\n')
# Out:
# df2 attended open house counts:
# No          100
# Yes          24
# Not Sure      7
# Name: event_open_house, dtype: int64
#
# df2 attended instant decision day counts:
# No          110
# Yes          13
# Not Sure      8
# Name: event_inst_dec_day, dtype: int64
#
# df2 attended campus info session counts:
# No          95
# Yes         26
# Not Sure    10
# Name: event_campus_info_sess, dtype: int64
#
# df2 attended titans tuesday info session counts:
# No          104
# Yes          19
# Not Sure      8
# Name: event_titans_tuesday_info_sess, dtype: int64
#
# df2 attended women who dare counts:
# No          125
# Not Sure      5
# Yes           1
# Name: event_women_who_dare, dtype: int64
#
# df2 attended regional college fair counts:
# No          114
# Yes          10
# Not Sure      7
# Name: event_regional_college_fair, dtype: int64
#
# df2 attended highschool sharetime info session counts:
# No          109
# Yes          16
# Not Sure      6
# ...

# %%
plt.hist(df2.event_campus_visit)
# Out:
# (array([95.,  0.,  0.,  0.,  0.,  6.,  0.,  0.,  0., 30.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Insights:
# ### The most attended event was the individual campus visit. With 30 people reported attending.
# #### The other most attended events were the campus info sessions (26),  the highschool info sessions (25), the open house event (24), and titans tuesday info sessions (19). Information sessions were most likely to be attended while most events overall were not attended, or they were unsure.

# %%
df2.groupby(['event_campus_visit', 'interest']).count()
# Out:
#                              Unnamed: 0  gender  race  age  course  \
# event_campus_visit interest
# No                 1                 18      18    18   18      18
#                    2                 22      22    22   22      22
#                    3                 41      41    41   41      41
#                    4                  8       8     8    8       8
#                    5                  6       6     6    6       6
# Not Sure           1                  2       2     2    2       2
#                    3                  4       4     4    4       4
# Yes                1                  6       6     6    6       6
#                    2                 10      10    10   10      10
#                    3                  9       9     9    9       9
#                    4                  4       4     4    4       4
#                    5                  1       1     1    1       1
#
# ...

# %%
df2.groupby(['event_campus_info_sess', 'interest']).count()
# Out:
#                                  Unnamed: 0  gender  race  age  course  \
# event_campus_info_sess interest
# No                     1                 20      20    20   20      20
#                        2                 25      25    25   25      25
#                        3                 39      39    39   39      39
#                        4                  7       7     7    7       7
#                        5                  4       4     4    4       4
# Not Sure               1                  2       2     2    2       2
#                        3                  6       6     6    6       6
#                        5                  2       2     2    2       2
# Yes                    1                  4       4     4    4       4
#                        2                  7       7     7    7       7
#                        3                  9       9     9    9       9
#                        4                  5       5     5    5       5
# ...

# %%
df2.groupby(['event_hs_info_sess', 'interest']).count()
# Out:
#                              Unnamed: 0  gender  race  age  course  \
# event_hs_info_sess interest
# No                 1                 23      23    23   23      23
#                    2                 22      22    22   22      22
#                    3                 42      42    42   42      42
#                    4                  7       7     7    7       7
#                    5                  5       5     5    5       5
# Not Sure           2                  1       1     1    1       1
#                    3                  5       5     5    5       5
#                    5                  1       1     1    1       1
# Yes                1                  3       3     3    3       3
#                    2                  9       9     9    9       9
#                    3                  7       7     7    7       7
#                    4                  5       5     5    5       5
#                    5                  1       1     1    1       1
# ...

# %%
df2.groupby(['event_open_house', 'interest']).count()
# Out:
#                            Unnamed: 0  gender  race  age  course  \
# event_open_house interest
# No               1                 20      20    20   20      20
#                  2                 26      26    26   26      26
#                  3                 39      39    39   39      39
#                  4                 11      11    11   11      11
#                  5                  4       4     4    4       4
# Not Sure         1                  2       2     2    2       2
#                  3                  4       4     4    4       4
#                  5                  1       1     1    1       1
# Yes              1                  4       4     4    4       4
#                  2                  6       6     6    6       6
#                  3                 11      11    11   11      11
#                  4                  1       1     1    1       1
#                  5                  2       2     2    2       2
#
# ...

# %%
plt.hist(df2.interest)
# Out:
# (array([26.,  0., 32.,  0.,  0., 54.,  0., 12.,  0.,  7.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Insights:
# ### While most all of interest related reports were people saying they were mildly interested (3/5), two people who went to the open house confirmed that they were extremely interested (5/5).
# #### Two extremely excited people may not seem like a lot, but it was the least common response proving anyone reporting it was significant.
# #### The other most attended events only had one each who confirmed they were extremely interested (5/5), but they had more who said they were mildly interested (4/5).
# ### It appears that the information sessions overall were most attended, and the people who attended them expressed more mild interest. The open house had an extra person who was extremely interested, but it lacked in people who were mildly interested.
